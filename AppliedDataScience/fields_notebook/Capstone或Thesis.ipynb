# %%
import pandas as pd
import sys
import os
import json
from tqdm import tqdm
sys.path.append('/Users/yijingyang/Library/CloudStorage/OneDrive-个人/GradPilot/ProgramDB/AppliedDataScience')
import asyncio
from call_api import call_gemini, async_call_gemini
from tqdm.asyncio import tqdm_asyncio

field_name = "Capstone或Thesis"
field_path = f"/Users/yijingyang/Library/CloudStorage/OneDrive-个人/GradPilot/ProgramDB/AppliedDataScience/fields_csv/{field_name}.csv"
field_df = pd.read_csv(field_path)

field_df.shape
# Out:
# (121, 9)

# %%
prompt_template = """
You are an assistant whose single task is to identify **all graduation requirements that go beyond regular coursework** for the graduate program below.

These non-coursework requirements may include, but are not limited to:
• Capstone project • Research thesis • Comprehensive/qualifying exam  
• Internship / practicum hours • Mandatory fieldwork or research‐lab hours  
• Professional portfolio • Residency / clinical experience

────────────────────────────────────────────────────────
🔍  How to locate the information

1. **Use primary university sources only**  
   • Follow the Admissions and Program URLs given.  
   • You may open additional pages that live under the same university’s *.edu* domain (e.g., “Degree Requirements”, “Program Handbook”, “Curriculum”).  
   ⛔  Ignore every non-*.edu* website, news article, or secondary aggregate.

2. **Search guideline (if needed)**  
   Run a single Google search:  
   "{university} {department} {degree} {program} graduation requirement capstone thesis practicum exam site:.edu"  
   Check only *.edu* results until you find an authoritative statement of requirements.

3. **What to output**  
   • Summarize the requirement(s) in **one concise sentence**—no quotes, no explanations.  
   • If multiple options exist, describe them briefly (e.g., “Capstone or thesis option”).  
   • If the program states there are *no* additional requirements, say so (e.g., “No additional graduation requirement”).  
   • If you do **not** find a clear statement from an *.edu* source, output **Not found**—never guess or invent.

────────────────────────────────────────────────────────
⚠️  **Output format (one line, no quotes, no extra text)**  
Valid examples:

Capstone project required  
Research thesis mandatory  
Capstone or thesis option available  
Industry internship of at least 400 hours required  
Comprehensive exam required  
No additional graduation requirement  
Not found  

────────────────────────────────────────────────────────
Pages to consult first:
• Admissions URL: {admissions_url}  
• Program URL:    {program_url}

What non-coursework graduation requirement applies to this program?
"""

# %%
import os
import json
import asyncio
from tqdm.asyncio import tqdm_asyncio

# Async Gemini wrapper
from call_api import async_call_gemini

# ---------------------------------------------------------------------------
# Concurrency guard – avoid hitting rate-limits
# ---------------------------------------------------------------------------
semaphore = asyncio.Semaphore(2)            # max concurrent rows

# ---------------------------------------------------------------------------
# Per-row worker
# ---------------------------------------------------------------------------
async def process_row(row, prompt_template, num_vote: int, model_name: str):
    """
    1. Format the prompt for this row
    2. Launch `num_vote` Gemini calls in parallel
    3. Capture BOTH normal answers *and* every possible error case
    4. Return a serialisable record
    """
    async with semaphore:
        row    = row.to_dict()
        prompt = prompt_template.format(
            university     = row["大学英文名称"],
            degree         = row["学位"],
            program        = row["专业英文名称"],
            department     = row["所属院系（英文）"],
            admissions_url = row["招生网址"],
            program_url    = row["专业网址"],
        )

        record: dict = row.copy()
        record["llm_reponses"] = {}

        # -------- launch Gemini calls in parallel --------------------
        tasks = [
            async_call_gemini(
                prompt,
                model_name=model_name,
                use_search=True,
                url_context=True
            )
            for _ in range(num_vote)
        ]
        responses = await asyncio.gather(*tasks)

        # -------- post-process each response -------------------------
        for i, response in enumerate(responses):
            resp_key = f"response {i+1}"

            # -- 1. Transport / server-side errors (string starting "Error:")
            if isinstance(response, str) and response.startswith("Error:"):
                record["llm_reponses"][resp_key] = {
                    "error": response                       # e.g. "Error: 429 Rate limit …"
                }
                continue

            # -- 2. Empty / malformed response objects
            if not hasattr(response, "candidates") or not response.candidates:
                record["llm_reponses"][resp_key] = {
                    "error": "No candidates returned",
                    "raw_response": str(response)
                }
                continue

            # -- 3. Extract main answer text
            try:
                text = response.candidates[0].content.parts[0].text
            except Exception as e:
                record["llm_reponses"][resp_key] = {
                    "error": f"Cannot parse text: {e}",
                    "raw_response": str(response)
                }
                continue

            # -- 4. Extract additional metadata (best-effort)
            try:
                url_context = str(response.candidates[0].url_context_metadata)
            except Exception:
                url_context = "Not used"

            try:
                search_pages = (
                    f"Search Chunks: "
                    f"{response.candidates[0].grounding_metadata.grounding_chunks}"
                )
            except Exception:
                search_pages = "Not used"

            try:
                search_queries = (
                    f"Search Query: "
                    f"{response.candidates[0].grounding_metadata.web_search_queries}"
                )
            except Exception:
                search_queries = "Not used"

            try:
                search_support = (
                    f"Search Supports: "
                    f"{response.candidates[0].grounding_metadata.groundingSupports}"
                )
            except Exception:
                search_support = "Not used"

            # -- 5. Store normal answer + metadata + raw object
            record["llm_reponses"][resp_key] = {
                "response_text": text,
                "url_context": url_context,
                "search_queries": search_queries,
                "search_pages": search_pages,
                "search_support": search_support,
                "raw_response": str(response)             # keep for deep-debugging
            }

        return record

# ---------------------------------------------------------------------------
# Batch orchestrator with tqdm progress bar
# ---------------------------------------------------------------------------
async def request_and_store_async(prompt_template,
                                  field_df,
                                  num_vote: int,
                                  model_name: str,
                                  start_from: int = 0,
                                  end_at: int = -1):
    """
    Runs `process_row` over the dataframe slice asynchronously,
    shows a live tqdm bar, and dumps the results to JSON.
    """
    df = field_df.copy()[start_from:end_at]

    # Spawn tasks for every row in the slice
    tasks = [
        process_row(row, prompt_template, num_vote, model_name)
        for _, row in df.iterrows()
    ]

    # tqdm_asyncio.gather gives us progress updates as tasks complete
    response_records = await tqdm_asyncio.gather(*tasks)

    # Persist to disk ------------------------------------------------
    output_dir = f"../fields_records/{field_name}"
    os.makedirs(output_dir, exist_ok=True)
    output_path = f"{output_dir}/{field_name}_{model_name}_{start_from}_{end_at}.json"

    with open(output_path, "w") as f:
        json.dump(response_records, f, ensure_ascii=False, indent=2)

    return response_records

# %%
import nest_asyncio
nest_asyncio.apply()  # Only needed in Jupyter

num_vote = 3
start_from = 0
end_at = len(field_df)
model_name = "gemini-2.5-flash"
response_records = asyncio.run(
    request_and_store_async(prompt_template, field_df, num_vote, model_name, start_from=start_from, end_at=end_at)
)
# Out:
#   0%|          | 0/121 [00:00<?, ?it/s]
# 100%|██████████| 121/121 [17:37<00:00,  8.74s/it]

# %%
# 使用示例
json_file_path = "/Users/yijingyang/Library/CloudStorage/OneDrive-个人/GradPilot/ProgramDB/AppliedDataScience/fields_records/Capstone或Thesis/Capstone或Thesis_gemini-2.5-flash_0_121.json"
output_dir = "/Users/yijingyang/Library/CloudStorage/OneDrive-个人/GradPilot/ProgramDB/AppliedDataScience/fields_records/Capstone或Thesis"

# %%
import json
import os

def extract_responses_from_json(json_file_path, output_dir):
    """
    从JSON文件中提取所有response_text并打印，同时保存到txt文件
    
    Args:
        json_file_path (str): JSON文件路径
        output_dir (str): 输出目录路径
    """
    
    # 读取JSON文件
    with open(json_file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    # 创建输出目录
    os.makedirs(output_dir, exist_ok=True)
    
    # 获取文件名（不含扩展名）
    file_name = os.path.basename(json_file_path).replace('.json', '')
    output_txt_path = os.path.join(output_dir, f"{file_name}_responses.txt")
    
    all_responses = []
    response_count = 0
    
    print(f"正在处理文件: {json_file_path}")
    print(f"总项目数: {len(data)}")
    print("\n" + "="*80)
    
    # 遍历所有项目
    for i, project in enumerate(data):
        university = project.get('大学英文名称', 'Unknown University')
        degree = project.get('学位', 'Unknown Degree')
        major = project.get('专业英文名称', 'Unknown Major')
        
        project_header = f"\n项目 {i+1}: {university} - {degree} - {major}"
        print(project_header)
        all_responses.append(project_header)
        
        # 获取LLM回答
        llm_responses = project.get('llm_reponses', {})
        
        # 遍历每个回答
        for resp_key in ['response 1', 'response 2', 'response 3']:
            if resp_key in llm_responses:
                resp_data = llm_responses[resp_key]
                response_text = resp_data.get('response_text', 'No response text')
                
                response_line = f"  {resp_key}: {response_text}"
                print(response_line)
                all_responses.append(response_line)
                response_count += 1
            else:
                missing_line = f"  {resp_key}: [缺失回答]"
                print(missing_line)
                all_responses.append(missing_line)
        
        print("-" * 60)
        all_responses.append("-" * 60)
    
    # 保存到txt文件
    with open(output_txt_path, 'w', encoding='utf-8') as f:
        f.write('\n'.join(all_responses))
    
    # 打印统计信息
    print(f"\n统计信息:")
    print(f"总项目数: {len(data)}")
    print(f"总回答数: {response_count}")
    print(f"平均每项目回答数: {response_count/len(data):.2f}")
    print(f"\n所有回答已保存到: {output_txt_path}")
    
    return output_txt_path
# 执行函数
output_file = extract_responses_from_json(json_file_path, output_dir)
# Out:
# 正在处理文件: /Users/yijingyang/Library/CloudStorage/OneDrive-个人/GradPilot/ProgramDB/AppliedDataScience/fields_records/Capstone或Thesis/Capstone或Thesis_gemini-2.5-flash_0_121.json
# 总项目数: 121
#
# ================================================================================
#
# 项目 1: Massachusetts Institute of Technology - Meng - Civil and Environmental Engineering：Data Science for Engineering Systems (DSES) track
#   response 1: MEng Thesis required.
#   response 2: Research thesis required.
#   response 3: Research thesis required.
# ------------------------------------------------------------
#
# 项目 2: Massachusetts Institute of Technology - PhD - Social and Engineering Systems
#   response 1: A written qualifying exam and an oral qualifying exam are required.
#   response 2: Not found
#   response 3: The PhD program in Social and Engineering Systems requires passing written and oral qualifying exams, completing a teaching trainee service, and successfully proposing, defending, and submitting a research thesis.
# ------------------------------------------------------------
#
# 项目 3: Massachusetts Institute of Technology - MAS - Data, Economics, and Development Policy
#   response 1: Capstone project required.
#   response 2: Capstone project required.
#   response 3: The first URL (oge.mit.edu) states: "In your research statement, present a research topic that you could imagine pursuing during your summer capstone project." and "Note that you do not need to complete a full research study during your summer capstone project."
#
# The second URL (economics.mit.edu) states: "Learners admitted to the DEDP program complete one semester of coursework at MIT and an approved capstone project."
#
# Both sources clearly indicate that a capstone project is a graduation requirement.
# ------------------------------------------------------------
#
# 项目 4: Harvard University - MPP - Master in Public Policy
#   response 1: The provided URLs mainly discuss application requirements, prerequisites, and a specific "Data and Research Methods track" which involves completing a certain number of course credits. Neither page explicitly states non-coursework graduation requirements like a capstone, thesis, or comprehensive exam for the general MPP program. The "Data and Research Methods track" mentions a "final capstone assessment" but only for Public Leadership Credential (PLC) Pathway applicants to the MC/MPA Program, not the MPP program directly.
#
# Therefore, I need to perform a search to find more specific graduation requirements for the MPP program.
#   response 2: The first URL, "How to Apply", discusses application requirements, prerequisites, and essays, but does not mention graduation requirements beyond coursework.
# The second URL, "Introducing the Data and Research Methods track", describes an optional track within the MPP, MPA, and MC/MPA programs. It states that students pursuing this track must "Enroll in and fulfill all MPP, MPA, or MC/MPA Program degree requirements" and complete additional coursework, but it doesn't specify any non-coursework graduation requirements for the general MPP program itself.
#
# Since neither of the initial URLs provides the specific non-coursework graduation requirements for the general MPP program, I will now use the suggested search query.
#   response 3: The first URL (Admissions) provides information about application requirements, but it does not mention any *graduation* requirements beyond coursework for the MPP program. It discusses prerequisites, GRE/GMAT, essays, recommendations, and transcripts.
#
# The second URL (Data and Research Methods track) describes an optional track within the MPP, MPA, and MC/MPA programs. It states that students pursuing this track must "Enroll in and fulfill all MPP, MPA, or MC/MPA Program degree requirements" and "Complete at least 16 course credits from a list of qualifying courses". This indicates that the track itself is coursework-based, and it doesn't specify additional non-coursework graduation requirements for the *main* MPP degree.
#
# I need to find the general graduation requirements for the MPP program, not just an optional track. I will perform a targeted search.
# ------------------------------------------------------------
#
# 项目 5: Harvard University - MPP / ID - Master in Public Administration in International Development
#   response 1: A development-related internship and a Second-Year Policy Analysis are required.
#   response 2: A development-related internship and a Second-Year Policy Analysis are required.
#   response 3: The first URL, "How to Apply", provides general admission information and prerequisites for various master's programs, including the MPA/ID. It does not mention any non-coursework graduation requirements. It discusses GRE/GMAT, essays, resumes, recommendations, and transcripts.
#
# The second URL, "Introducing the Data and Research Methods track", discusses an optional STEM-designated track for MPP, MPA, and MC/MPA students, and notes that the MPA/ID program is already STEM-designated. It mentions completing a certain number of course credits from qualifying courses, but these are still coursework requirements. It does not mention any non-coursework graduation requirements beyond regular coursework for the general MPA/ID program.
#
# I need to search for more information. I will use the suggested search query.
# ------------------------------------------------------------
#
# 项目 6: Harvard University - MPP - Master in Public Administration
#   response 1: The first URL is about "How to Apply" and mainly covers prerequisites, application components (essays, GRE/GMAT, recommendations, transcripts), and English proficiency. It does not explicitly state non-coursework graduation requirements for the MPP program.
#
# The second URL introduces the "Data and Research Methods track" which is a STEM-designated pathway for MPP, MPA, and MC/MPA students. It specifies that students must "Enroll in and fulfill all MPP, MPA, or MC/MPA Program degree requirements" and complete specific coursework within this track. However, it does not mention any *additional* non-coursework requirements beyond regular coursework for the general MPP degree itself.
#
# I need to look for general graduation requirements for the MPP program, not just a specific track. Since the provided URLs don't explicitly state non-coursework graduation requirements for the MPP, I will now use the search tool as per the instructions.
#
# Search query: "Harvard University Harvard Kennedy School MPP Master in Public Administration graduation requirement capstone thesis practicum exam site:.edu"
#   response 2: The Master in Public Policy program requires capstone experiences, including a Spring Exercise and a Policy Analysis Exercise (PAE).
#   response 3: Capstone experiences, including a Spring Exercise and a Policy Analysis Exercise (PAE), are required.
# ------------------------------------------------------------
#
# 项目 7: Harvard University - MC/MPA - Mid-Career Master in Public Administration
#   response 1: No additional graduation requirement.
#   response 2: No additional graduation requirement.
#   response 3: No additional graduation requirement.
# ------------------------------------------------------------
#
# 项目 8: Stanford University - PhD - ‌Education Data Science
#   response 1: Not found.
#   response 2: Not found
#   response 3: Not found.
# ------------------------------------------------------------
#
# 项目 9: Stanford University - MS - Education Data Science (MS)
#   response 1: Not found
#   response 2: Capstone project required.
#   response 3: A capstone project is required.
# ------------------------------------------------------------
#
# 项目 10: Stanford University - PhD - Biomedical Data Science
#   response 1: A qualifying exam and a research thesis are required.
#   response 2: The Biomedical Data Science PhD program requires a qualifying exam, a thesis pre-proposal seminar, a dissertation, and a teaching assistantship.
#   response 3: A qualifying exam, a thesis pre-proposal seminar, and a dissertation are required.
# ------------------------------------------------------------
#
# 项目 11: Stanford University - MS - Biomedical Data Science
#   response 1: A research project is required for the Academic (Research) MS degree.
#   response 2: Research project required.
#   response 3: A research project is required for the Academic (Research) MS degree.
# ------------------------------------------------------------
#
# 项目 12: University of Pennsylvania - MUSA - Master of Urban Spatial Analytics
#   response 1: Practicum or capstone project required.
#   response 2: Practicum or capstone project required.
#   response 3: Practicum or capstone project required.
# ------------------------------------------------------------
#
# 项目 13: University of Pennsylvania - MSSP + DA - Social Policy+Data Analytics for Social Policy Certificate
#   response 1: A capstone seminar and a policy internship of at least 150 hours are required.
#   response 2: Capstone project and a policy internship of at least 150 hours required.
#   response 3: The first URL (sp3.upenn.edu) did not load, but the second URL (sp2.upenn.edu) provided a lot of information.
#
# From the content of `https://sp2.upenn.edu/program/master-of-science-in-social-policy-data-analytics-for-social-policy-certificate/`:
#
# *   Under "Director's Welcome", it states: "Policy internships and projects will give you the opportunity to apply your skills in real-world settings." and "In addition to our rigorous academic training, you will gain real-world experience through a policy internship that will connect you with policy practitioners and organizations in multiple sectors and settings."
# *   Under "The SP2 Difference", it mentions: "Gain hands-on, career-focused experience through policy internships in data analytics" and "Engage in practical policy research in the Data for Equitable Justice Lab".
# *   Under "Curriculum", in the "3rd Semester (Fall)" section, it lists: "MSSP 6380: MSSP+DA Capstone Seminar: Telling Stories with Data (1CU)" and "MSSP 6390: MSSP+DA Policy Internship in Data Analytics Seminar (0CU)".
# *   Under "Social Policy Internship", it explicitly states: "The MSSP+DA program provides students with competitive and cutting-edge opportunities to complete policy internships in data analytics... Credit for internships is incorporated into the MSSP+DA Capstone Seminar, and students most often complete the internship in their final spring semester. The Data Analytics policy internship must consist of a minimum commitment of 150 hours."
#
# So, there are two clear non-coursework requirements: a Capstone Seminar and a Policy Internship. The internship is explicitly stated to be a minimum of 150 hours.
#
# Let's synthesize this into one concise sentence.
#
# Capstone seminar and a policy internship of at least 150 hours required.
# Capstone seminar and a minimum 150-hour policy internship are required.
# ------------------------------------------------------------
#
# 项目 14:
# Brown University - MS - Social Data Analytics
#   response 1: No additional graduation requirement.
#   response 2: No additional graduation requirement
#   response 3: No additional graduation requirement
# ------------------------------------------------------------
#
# 项目 15: Columbia University - M.A. - Master of Science (M.S.) in Data, Learning, and Society
#   response 1: A capstone project or research practicum is required.
#   response 2: Capstone project or research practicum required.
#   response 3: A capstone project or research practicum is required.
# ------------------------------------------------------------
#
# 项目 16: Columbia University - MA - Quantitative Methods in the Social Sciences
#   response 1: No response text
#   response 2: Master's thesis required.
#   response 3: No response text
# ------------------------------------------------------------
#
# 项目 17: Cornell University - M.S. - Biostatistics and Data Science
#   response 1: A mentored research project providing hands-on experience is required.
#   response 2: Mentored research project required.
#   response 3: No response text
# ------------------------------------------------------------
#
# 项目 18: University of Chicago - MSCAPP - MS in Computational Analysis and Public Policy
#   response 1: The MSCAPP program often involves a capstone project or thesis.
#   response 2: A capstone project or thesis involving the application of computational and analytical methods to real-world policy issues is often required.
#   response 3: The Admissions URL primarily focuses on application requirements (transcripts, recommendations, GRE, etc.) and deadlines. It mentions "Degree Programs" under "Academics" and lists "MS in Computational Analysis and Public Policy." It also mentions "Practical Experience" as part of "Design Your Path" but doesn't explicitly state it as a *graduation requirement* for MSCAPP. It also states: "The motivation statement requirement does not apply to MS in Computational Analysis and Public Policy (MSCAPP) program, which instead requires MSCAPP applicants to answer supplemental short answer questions." This is about application, not graduation.
#
# The Program URL provides an overview of the MSCAPP program, including "About," "Curriculum," "People," "Outcomes," "Opportunities," "Profiles," "Admissions," and "FAQ." I need to delve deeper into these sections, especially "Curriculum" or "Opportunities," to find graduation requirements. The page has links like "Learn more" under each section. I will start by browsing the "Curriculum" link to see if it lists graduation requirements.
#
# The Admissions page also mentions "BA Thesis Process" and "Capstone Projects" under "Undergraduate Program," but this is for undergraduate students, not graduate.
#
# I will browse the Curriculum page from the Program URL. The direct link is not provided on the main page, so I need to find it by examining the page structure. Looking at the navigation, it seems like `https://capp.uchicago.edu/curriculum` would be the correct path.
# ------------------------------------------------------------
#
# 项目 19: University of Chicago - M.S.  - MS in Environmental Science
#   response 1: Capstone project required
#   response 2: Capstone project required
#   response 3: Capstone project required.
# ------------------------------------------------------------
#
# 项目 20: University of Chicago - MAPSS - Quantitative Methods & Social Analysis
#   response 1: Thesis or capstone project required.
#   response 2: Thesis or capstone project required.
#   response 3: Thesis or capstone project required.
# ------------------------------------------------------------
#
# 项目 21: University of Chicago - MACSS - Computational Social Science
#   response 1: An MA thesis (academic or professional option) is required.
#   response 2: A master's thesis is required for graduation, with options for an academic or professional thesis.
#   response 3: Research thesis required.
# ------------------------------------------------------------
#
# 项目 22: University of Chicago - MACSS - Computational Social Science ：economics
#   response 1: Research thesis required.
#   response 2: Research thesis required.
#   response 3: No response text
# ------------------------------------------------------------
#
# 项目 23: University of California, Berkeley - M.A. - Master of Computational Social Science (MaCSS)
#   response 1: Capstone project and qualifying exam required.
#   response 2: A capstone project is required, and students must complete a boot camp or pass waiver exams in advanced statistics and computational methods.
#   response 3: A capstone project is required, and students must complete two summer boot camp courses or pass two waiver exams.
# ------------------------------------------------------------
#
# 项目 24: Rice University - PSM - Applied Chemical Sciences ：Computational Chemistry and Data Science
#   response 1: Required internship or a capstone/research project.
#   response 2: No response text
#   response 3: No additional graduation requirement.
# ------------------------------------------------------------
#
# 项目 25: Rice University - PSM - Applied Chemical Sciences ：Computational Chemistry and Data Science
#   response 1: An internship or capstone/research project is required.
#   response 2: No additional graduation requirement.
#   response 3: The
# ------------------------------------------------------------
#
# 项目 26: University of Michigan, Ann Arbor - Ph.D - Survey and Data Science
#   response 1: The program requires completion of Responsible Conduct of Research and Scholarship (RCRS) Training, achieving candidacy, a prospectus proposal, a qualifying and comprehensive examination, and writing and defending a doctoral dissertation.
#   response 2: The non-coursework graduation requirements include completion of Responsible Conduct of Research and Scholarship training, successful completion of a qualifying and comprehensive examination, a final paper and presentation, a prospectus proposal, and writing and defending a doctoral dissertation.
#   response 3: Qualifying and comprehensive examinations and a doctoral dissertation with defense are required.
# ------------------------------------------------------------
#
# 项目 27: University of Michigan, Ann Arbor - MS - Survey and Data Science
#   response 1: Approved internship experience and attendance at 75% of scheduled department seminar series and professional development events are required.
#   response 2: An approved internship experience and attendance at 75% of scheduled department seminar series and professional development events are required.
#   response 3: Internship experience and attendance at 75% of scheduled department seminar series and professional development events required.
# ------------------------------------------------------------
#
# 项目 28: Georgetown University - M.S. - Data Science for Public Policy
#   response 1: No additional graduation requirement
#   response 2: A formal internship of at least 120 hours is required.
#   response 3: An internship of at least 120 hours is required, with a waiver option based on prior experience.
# ------------------------------------------------------------
#
# 项目 29: University of Virginia - ME - Biomedical Engineering
#   response 1: A design project is required.
#   response 2: Capstone project required.
#   response 3: A supervised research and design project is required, culminating in a written report and public presentations.
# ------------------------------------------------------------
#
# 项目 30: Carnegie Mellon University - MSPPM - MACHINE LEARNING & PUBLIC POLICY
#   response 1: A summer internship and a Systems Synthesis project (capstone) are required.
#   response 2: Internship and capstone project required.
#   response 3: Internship required, except for the three-semester track.
# ------------------------------------------------------------
#
# 项目 31: Carnegie Mellon University - Ph.D. - Societal Computing
#   response 1: Qualifying exams and a dissertation are required.
#   response 2: Research thesis and qualifying exams are required.
#   response 3: Research thesis, qualifying exam, two semesters of practicum, and two semesters as a teaching assistant are required.
# ------------------------------------------------------------
#
# 项目 32: Washington University in St. Louis - MSBDS - Master of Science in Biostatistics and Data Science (MSBDS)
#   response 1: Internship or mentored research experience required.
#   response 2: Internship or mentored research experience required.
#   response 3: Internship or mentored research experience required.
# ------------------------------------------------------------
#
# 项目 33: Washington University in St. Louis - PHD - Biomedical Informatics and Data Science
#   response 1: Graduation requirements include passing examinations, fulfilling a Mentored Experience Requirement, and completing a research dissertation.
#   response 2: Doctoral students must pass a qualifying exam, fulfill a department-defined mentored experience requirement (teaching or professional), and complete and defend a dissertation.
#   response 3: Qualifying examinations, a mentored experience, a research dissertation, and its defense are required.
# ------------------------------------------------------------
#
# 项目 34: University of California, San Diego - MS - COMPUTATIONAL SOCIAL SCIENCE
#   response 1: Capstone project required.
#   response 2: Capstone project required.
#   response 3: The program URL clearly states: "The capstone project provides real-world, hands-on training in applying computational social science in a business, non-profit, organizational, or research setting, culminating in a portfolio-worthy project."
#
# This directly answers the question about non-coursework graduation requirements.Capstone project required
# ------------------------------------------------------------
#
# 项目 35: University of California, San Diego - PhD - COMPUTATIONAL SOCIAL SCIENCE
#   response 1: Not found
#   response 2: The
#   response 3: No additional graduation requirement.
# ------------------------------------------------------------
#
# 项目 36: University of California, San Diego - PHD - Computational Biology and Data Science
#   response 1: The program requires successful completion of a doctoral dissertation and three examinations: preliminary assessment, research qualifying, and dissertation defense.
#   response 2: Not found
#   response 3: A preliminary assessment exam, a research qualifying exam, a dissertation defense examination, and a doctoral dissertation are required.
# ------------------------------------------------------------
#
# 项目 37: University of Southern California - M.S. - Communication Data Science
#   response 1: A non-credit Managing Complexity in Diverse Organizations course is required.
#   response 2: Not found
#   response 3: Not found
# ------------------------------------------------------------
#
# 项目 38: University of Southern California - M.S. - MS IN BIOMEDICAL ENGINEERING – BIOMEDICAL DATA ANALYTICS
#   response 1: Thesis option available.
#   response 2: No additional graduation requirement
#   response 3: Thesis option available.
# ------------------------------------------------------------
#
# 项目 39: University of Southern California - M.S. - Master of Science in Communication Data Science
#   response 1: No additional graduation requirement.
#   response 2: No additional graduation requirement.
#   response 3: No additional graduation requirement.
# ------------------------------------------------------------
#
# 项目 40: University of Southern California - M.S. - MS IN ENVIRONMENTAL DATA SCIENCE
#   response 1: No additional graduation requirement.
#   response 2: No additional graduation requirement.
#   response 3: No additional graduation requirement.
# ------------------------------------------------------------
#
# 项目 41: University of Southern California - M.S. - Spatial Data Science
#   response 1: A capstone course or research thesis is required.
#   response 2: Not found
#   response 3: Not found
# ------------------------------------------------------------
#
# 项目 42: University of Southern California - M.S. - M.S. in Spatial Economics and Data Analysis
#   response 1: No additional graduation requirement.
#   response 2: No additional graduation requirement.
#   response 3: No additional graduation requirement.
# ------------------------------------------------------------
#
# 项目 43: University of Southern California - M.S. - Public Policy Data Science
#   response 1: A capstone project is required.
#   response 2: Capstone project required.
#   response 3: The
# ------------------------------------------------------------
#
# 项目 44: University of California, Irvine - MENG - CIVIL AND ENVIRONMENTAL ENGINEERING
#   response 1: Capstone project required.
#   response 2: Capstone project required.
#   response 3: Capstone project required.
# ------------------------------------------------------------
#
# 项目 45: Georgia Institute of Technology - MS - Master of Science in Urban Analytics
#   response 1: A capstone project is required.
#   response 2: Capstone project required.
#   response 3: A capstone project is required.
# ------------------------------------------------------------
#
# 项目 46: University of California, Santa Barbara - MEDS - MASTER OF ENVIRONMENTAL DATA SCIENCE
#   response 1: A client-driven capstone project is required.
#   response 2: Capstone project required.
#   response 3: Capstone project required.
# ------------------------------------------------------------
#
# 项目 47: New York University - MS - Data Science – Biomedical Informatics Track
#   response 1: Capstone project required.
#   response 2: Capstone project required.
#   response 3: Capstone project required.
# ------------------------------------------------------------
#
# 项目 48: New York University - MS - Applied Statistics for Social Science Research (ASSR-MS)
#   response 1: The MS Applied Statistics for Social Science Research program requires an internship and a consulting research seminar.
#   response 2: A statistical consulting research seminar or an internship is required.
#   response 3: A statistical consulting research seminar is required.
# ------------------------------------------------------------
#
# 项目 49: New York University - MS/MPA - Applied Statistics for Social Science Research (MS) / Public and Nonprofit Management (MPA) - Dual Degree (ASSD-MS)
#   response 1: A capstone culminating project is required.
#   response 2: The browsed pages provide information about the dual degree program, admissions requirements, curriculum overview (credits), and contact information. However, they do not explicitly state any non-coursework graduation requirements like a capstone, thesis, or comprehensive exam. The text mentions "Students graduate and receive a diploma from each school after successful completion of the dual-degree requirements for both degrees", but it doesn't specify what those requirements are beyond coursework.
#
# I will now perform the suggested search query to find more specific graduation requirements.
#   response 3: Capstone project required.
# ------------------------------------------------------------
#
# 项目 50: New York University - MS - Statistics and Computational Social Science
#   response 1: Doctoral dissertation required.
#   response 2: Statistical consulting research seminar required.
#   response 3: Research dissertation required.
# ------------------------------------------------------------
#
# 项目 51: University of Wisconsin, Madison - M.S. - Psychology：DATA SCIENCE IN HUMAN BEHAVIOR
#   response 1: A capstone project is required.
#   response 2: Capstone project required.
#   response 3: A capstone project is required.
# ------------------------------------------------------------
#
# 项目 52: University of Wisconsin, Madison - M.S. - Biomedical Data Science, M.S.
#   response 1: No additional graduation requirement.
#   response 2: A 4-credit research-based independent study is required.
#   response 3: No additional graduation requirement.
# ------------------------------------------------------------
#
# 项目 53: University of Wisconsin, Madison - Ph.D. - Biomedical Data Science, Ph.D.
#   response 1: Research rotations, an oral preliminary exam, a dissertation with a final oral defense, and a doctoral minor or graduate/professional certificate are required.
#   response 2: Research rotations, an oral preliminary exam, a dissertation, a final oral exam, and a doctoral minor or graduate/professional certificate are required.
#   response 3: Research rotations, an oral preliminary exam, a dissertation, and a final oral exam (dissertation defense) are required.
# ------------------------------------------------------------
#
# 项目 54: University of Illinois, Urbana-Champaign - MS - statistics-analytics
#   response 1: An experiential learning requirement can be fulfilled through a statistical consulting course, a professional statistics course, or an approved internship.
#   response 2: No response text
#   response 3: Experiential learning, fulfilled by an internship, statistical consulting, or professional preparation, is required.
# ------------------------------------------------------------
#
# 项目 55: University of Illinois, Urbana-Champaign - MS - statistics-analytics
#   response 1: An experiential learning requirement is fulfilled through a choice of statistical consulting, professional statistics, or an internship.
#   response 2: Experiential learning, including statistical consulting, professional statistics, or an approved internship, is required.
#   response 3: Experiential learning through statistical consulting, professional statistics, or an internship is required.
# ------------------------------------------------------------
#
# 项目 56: University of Washington - PHD - Bioengineering (PhD)：Data Science Option
#   response 1: Qualifying, general, and final examinations are required, along with laboratory rotations, teaching experience, and a doctoral dissertation.
#   response 2: Research dissertation, Qualifying Examination, General Examination, Final Examination, laboratory rotations, and teaching experience are required.
#   response 3: Qualifying, General, and Final Examinations, a dissertation, laboratory rotations, and a teaching experience are required.
# ------------------------------------------------------------
#
# 项目 57: University of Washington - PHD - Chemical Engineering (PhD)：Advanced Data Science Option
#   response 1: A research thesis, preliminary exam, general exam, and a Master of Science degree (thesis or non-thesis option) are required.
#   response 2: A preliminary exam, a general exam, and a dissertation are required.
#   response 3: Research thesis and comprehensive exams are required.
# ------------------------------------------------------------
#
# 项目 58: University of Washington - PHD - Civil & Environmental Engineering - Data Science Option
#   response 1: The
#   response 2: The
#   response 3: Research thesis, a general exam, and a final exam (dissertation defense) are required.
# ------------------------------------------------------------
#
# 项目 59: University of Washington - MSEE - Electrical Engineering (MSEE) - Seattle ：Data Science Option
#   response 1: Thesis option available.
#   response 2: Research thesis option available.
#   response 3: Graduation requires either a coursework-only option or a thesis with a final oral examination.
# ------------------------------------------------------------
#
# 项目 60: University of Washington - PHD - Electrical Engineering (PhD) - Seattle ：Data Science Option
#   response 1: A qualifying exam, general exam, dissertation research, and dissertation defense are required.
#   response 2: Qualifying exam, general exam, dissertation defense, and dissertation research are required.
#   response 3: A dissertation, qualifying exam, general exam, and dissertation defense are required.
# ------------------------------------------------------------
#
# 项目 61: University of Washington - PHD - Ph.D., Applied Mathematics: Advanced Data Science
#   response 1: The first URL could not be accessed. The second URL, `https://amath.washington.edu/phd-program`, provides detailed information about the Ph.D. program in Applied Mathematics.
#
# From the content of the Ph.D. Program page:
# - "The Doctor of Philosophy (Ph.D.) Degree in Applied Mathematics is primarily a research degree, and is not conferred as a result of course work. The granting of the degree is based on proficiency in Applied Mathematics, and the ability to carry out an independent investigation as demonstrated by the completion of a doctoral dissertation."
# - "Students in the Ph.D. program must pass the following exams: The qualifying exam, The general exam, The final exam (defense)"
#
# Based on this, the non-coursework requirements are a doctoral dissertation and three exams.
# Doctoral dissertation and three exams are required.
#   response 2: Doctoral dissertation, qualifying exam, general exam, and final exam are required.
#   response 3: Doctoral dissertation, qualifying exam, general exam, and final exam (defense) are required.
# ------------------------------------------------------------
#
# 项目 62: University of Washington - PHD - Ph.D., Psychology: Data Science Option
#   response 1: Research thesis and comprehensive/final examination are required.
#   response 2: A doctoral final examination and a dissertation are required.
#   response 3: A First Year Research Project, General Examination, and a Dissertation and Final Examination are required.
# ------------------------------------------------------------
#
# 项目 63: University of Washington - PHD - Statistics (PhD)-Statistics in the Social Sciences
#   response 1: The first URL failed to load. The second URL, https://stat.uw.edu/academics/graduate/programs/phd, contains detailed graduation requirements under the "Ph.D. Program" section.
#
# I need to extract the "non-coursework" requirements for the "Statistics in the Social Sciences (CSSS) Track".
#
# Looking at the "General Statistics Track" for common requirements that might apply to all tracks:
# - M.S. Theory Exam
# - Research Prelim Exam
# - Consulting (STAT 599)
# - Applied Data Analysis Project (STAT 597)
# - Statistics seminar participation (STAT 590)
# - Teaching requirement (Teaching Assistant)
# - General Exam
# - Dissertation Credits (STAT 800)
# - Passage of the Dissertation Defense
#
# Now, I will specifically look at the "Statistics in the Social Sciences (CSSS) Track" section to see if there are any specific additional requirements or modifications.
#
# The "Statistics in the Social Sciences (CSSS) Track" section states:
# - "Students in the Statistics in the Social Sciences (CSSS) Ph.D. track are required to take four numerically graded 500-level courses, including at least two CSSS courses or STAT courses cross-listed with CSSS, and at most two discipline-specific social science courses that together form a coherent program of study. These courses may be counted as the four required Ph.D.-level electives." - This refers to coursework.
# - "Additionally, students must complete at least three quarters of participation (one credit per quarter) in the CS&SS seminar (CSSS 590)." - This is similar to the general seminar participation.
#
# It seems the general requirements for the PhD program, which include non-coursework elements, apply to all tracks unless explicitly stated otherwise. The CSSS track just specifies its coursework electives and seminar participation.
#
# Therefore, the non-coursework requirements are likely those listed under the "General Statistics Track" that are not explicitly course numbers for credit, but rather activities or exams.
#
# Let's re-evaluate the "General Statistics Track" for non-coursework items:
# - M.S. Theory Exam
# - Research Prelim Exam
# - Consulting (Requires enrollment in STAT 599, but the requirement is the consulting itself)
# - Applied Data Analysis Project (Requires enrollment in 3 credits of STAT 597, but the requirement is the project itself)
# - Statistics seminar participation (Students must attend the Statistics Department seminar and enroll in STAT 590 for at least 8 quarters - the participation is the requirement)
# - Teaching requirement (All Ph.D. students must satisfactorily serve as a Teaching Assistant for at least one quarter)
# - General Exam
# - Dissertation Credits (STAT 800) - This is coursework related to the dissertation.
# - Passage of the Dissertation Defense
#
# The key non-coursework requirements seem to be:
# - M.S. Theory Exam
# - Research Prelim Exam
# - Consulting
# - Applied Data Analysis Project
# - Statistics seminar participation
# - Teaching requirement
# - General Exam
# - Dissertation Defense
#
# The prompt asks for "one concise sentence" and examples like "Capstone or thesis option available" or "Comprehensive exam required".
#
# Given the detailed list, a "research thesis" is implied by "Dissertation Credits" and "Passage of the Dissertation Defense". "Comprehensive exam" is covered by "M.S. Theory Exam", "Research Prelim Exam", and "General Exam". "Consulting" and "Applied Data Analysis Project" are practical experiences. "Seminar participation" and "Teaching requirement" are also non-coursework activities.
#
# I need to synthesize this into one concise sentence, focusing on the main overarching non-coursework requirements. The most prominent ones are the exams and the dissertation/thesis.
#
# Let's try to combine them concisely.
# "M.S. Theory Exam, Research Prelim Exam, General Exam, Dissertation Defense, consulting, applied data analysis project, seminar participation, and a teaching requirement are mandatory."
#
# This is a bit long for "one concise sentence". I should try to group them.
# The exams are comprehensive/qualifying exams.
# The dissertation is a research thesis.
# Consulting and applied data analysis project are akin to practical work or projects.
# Seminar participation and teaching requirement are also additional activities.
#
# Let's simplify.
# "Comprehensive examinations, a research dissertation with defense, consulting, an applied data analysis project, seminar participation, and a teaching requirement are mandatory."
#
# This still feels a bit long. The prompt examples are very short.
# "Comprehensive exam required" or "Research thesis mandatory".
#
# Maybe I should focus on the most significant ones for a PhD, which are typically comprehensive/qualifying exams and a dissertation/thesis. The other items are also important but might be considered components of the overall program rather than "beyond regular coursework" in the same vein as a capstone or thesis. However, the prompt explicitly lists "Internship / practicum hours" and "Mandatory fieldwork or research‐lab hours" which consulting and applied data analysis could fall under.
#
# Let's re-read the prompt: "all graduation requirements that go beyond regular coursework".
# So, all items listed are relevant.
#
# I need to find the most concise way to combine these.
# "Comprehensive and preliminary exams, a research dissertation with defense, consulting, an applied data analysis project, seminar participation, and a teaching requirement are mandatory."
#
# Let's consider the example format: "Capstone project required", "Research thesis mandatory".
# If I list everything, it becomes a list. The prompt says "one concise sentence".
#
# The general exam and dissertation are typically the final hurdles for a PhD. The other items are also requirements.
#
# Let me try to phrase it like: "Multiple comprehensive and preliminary exams, a research dissertation with defense, consulting, an applied data analysis project, seminar participation, and a teaching requirement are mandatory."
#
# Let's try to categorize.
# Exams: M.S. Theory Exam, Research Prelim Exam, General Exam. These are comprehensive/qualifying exams.
# Research: Dissertation and Dissertation Defense. This is a research thesis.
# Practical: Consulting, Applied Data Analysis Project.
# Other: Statistics seminar participation, Teaching requirement.
#
# "Comprehensive and preliminary exams, a research dissertation with defense, an applied data analysis project, consulting, seminar participation, and a teaching assistantship are required."
#
# This is still a long sentence.
# Could I simplify to say "Exams, a dissertation, practical projects, and a teaching requirement"?
# This might be too vague.
#
# Let's stick to the specific names if possible but combine them for conciseness.
# "M.S. Theory, Research Prelim, and General Exams; a research dissertation with defense; consulting; an applied data analysis project; seminar participation; and a teaching requirement are mandatory."
#
# This is a list, but it's in one sentence. It adheres to "all graduation requirements that go beyond regular coursework".
#
# Let me re-check the example format: "Capstone project required", "Research thesis mandatory".
# This implies a very short, specific answer. If there are many, how do I handle it?
# "If multiple options exist, describe them briefly (e.g., “Capstone or thesis option”)." This implies choices, not a long list of distinct requirements.
#
# Given the strict "one concise sentence" and "no explanations", simply listing them might be the best approach if they cannot be grouped under a single umbrella term.
#
# However, "Comprehensive/qualifying exam" and "Research thesis" are already umbrella terms provided by the prompt.
#
# So, I can definitely say "Comprehensive exams and a research thesis with defense are required."
# But then I miss consulting, applied data analysis, seminar, and teaching.
#
# Let's re-read the "What to output" section carefully:
# "• Summarize the requirement(s) in one concise sentence—no quotes, no explanations.
# • If multiple options exist, describe them briefly (e.g., “Capstone or thesis option”).
# • If the program states there are no additional requirements, say so (e.g., “No additional graduation requirement”).
# • If you do not find a clear statement from an .edu source, output Not found—never guess or invent."
#
# The requirements are distinct, not options. So the "multiple options" guidance doesn't directly apply for formatting a list of distinct items.
#
# Given the desired conciseness, perhaps the most significant non-coursework components of a PhD are the exams and the dissertation.
#
# Let's try to focus on the key requirements that define a PhD beyond just taking classes.
# These are typically passing comprehensive/qualifying exams and completing a dissertation.
#
# "Comprehensive and preliminary exams, a research dissertation with defense, and a teaching requirement are mandatory."
# This leaves out consulting, applied data analysis project, and seminar participation. Are these less significant "beyond coursework" requirements? The prompt asks for *all* requirements.
#
# Let's check the wording of the requirements from the source again:
# - M.S. Theory Exam
# - Research Prelim Exam
# - Consulting. Requires enrollment in STAT 599.
# - Applied Data Analysis Project. Requires enrollment in 3 credits of STAT 597.
# - Statistics seminar participation: Students must attend the Statistics Department seminar and enroll in STAT 590 for at least 8 quarters.
# - Teaching requirement: All Ph.D. students must satisfactorily serve as
#   response 2: The
#   response 3: The Ph.D. program requires a dissertation defense, a general exam, a research prelim exam, an M.S. theory exam, consulting, an applied data analysis project, statistics seminar participation, and a teaching assistantship.
# ------------------------------------------------------------
#
# 项目 64: University of Washington - MS - Aquatic & Fishery Sciences (MS)： DATA SCIENCE TRACK
#   response 1: Research thesis required.
#   response 2: The first URL, the Admissions URL, was not accessible.
# The second URL, the Program URL, contains relevant information.
# Under the "Master of Science (MS) Degree" section, it states: "The Master of Science (MS) degree, often precursory to the Doctor of Philosophy (PhD) degree, typically requires the student to complete a research-based thesis."
# It also mentions "Data Science Option", but it states that "The primary learning outcome for the SAFS DSO is for students to have professional working proficiency – gained through coursework – in data management, data visualization, software engineering (data focused), and statistical modeling." This suggests that the data science option's learning outcome is achieved through coursework and does not explicitly mention additional non-coursework requirements beyond the general MS thesis requirement.
#
# Therefore, the non-coursework requirement is a research-based thesis.
#   response 3: Research thesis typically required.
# ------------------------------------------------------------
#
# 项目 65: University of Washington - PHD - Aquatic & Fishery Sciences (PhD)： DATA SCIENCE TRACK
#   response 1: Dissertation research, qualifying examination, general examination, and a final examination are required.
#   response 2: Qualifying and general examinations, dissertation research, and a final examination are required.
#   response 3: Research dissertation and qualifying, general, and final examinations required.
# ------------------------------------------------------------
#
# 项目 66: University of Washington - PHD - Earth and Space Sciences (PhD) ： DATA SCIENCE  TRACK
#   response 1: A preliminary exam, general exam, final exam, research dissertation, experiential learning, and teaching experience are required.
#   response 2: A preliminary exam, a general exam involving a written dissertation research proposal and oral presentation, a final exam based on the dissertation, a dissertation, an experiential learning requirement, and a teaching experience requirement are mandated.
#   response 3: The non-coursework graduation requirements include a preliminary exam, a general exam with a dissertation research proposal and oral presentation, a final exam based on the dissertation and oral presentation, an experiential learning requirement, and a teaching experience requirement.
# ------------------------------------------------------------
#
# 项目 67: University of Washington - PHD - Atmospheric Sciences (PhD)： DATA SCIENCE  TRACK
#   response 1: Not found
#   response 2: A dissertation and general examination are required.
#   response 3: A research dissertation, a general examination, and a final examination (dissertation defense) are required.
# ------------------------------------------------------------
#
# 项目 68: University of Washington - PHD - Atmospheric Sciences (PhD)：ADVANCED DATA SCIENCE (ADS) TRACK
#   response 1: Not found
#   response 2: Thesis and qualifying exam required.
#   response 3: Not found
# ------------------------------------------------------------
#
# 项目 69: University of Washington - PHD -  PhD (Public Policy & Management) ： DATA SCIENCE  TRACK
#   response 1: Qualifying exams, a major area paper, a teaching assistantship, a general exam to propose the dissertation, dissertation work, and a final dissertation defense are required.
#   response 2: No response text
#   response 3: The
# ------------------------------------------------------------
#
# 项目 70: University of Washington - PHD -  PhD (Public Policy & Management) ：ADVANCED DATA SCIENCE (ADS) TRACK
#   response 1: Qualifying exams, a major area paper, a teaching assistantship, and a dissertation with a general exam and final defense are required.
#   response 2: A dissertation, including a major area paper as its literature review, is required.
#   response 3: Not found
# ------------------------------------------------------------
#
# 项目 71: Rutgers University, New Brunswick - MPI - Master of Public Informatics
#   response 1: Not found
#   response 2: Not found
#   response 3: No additional graduation requirement.
# ------------------------------------------------------------
#
# 项目 72: Rutgers University, New Brunswick - MPI - Master of Public Informatics
#   response 1: No additional graduation requirement.
#   response 2: Not found
#   response 3: The browsed pages provide general information about the MPI program, including admission requirements, curriculum (core courses and electives), concentrations, and career opportunities. However, neither page explicitly states non-coursework graduation requirements such as a capstone project, thesis, or comprehensive exam for the Master of Public Informatics program. The "Projects" section on the MPI page mentions "excellent state-of-the-art research driven project opportunities" and "students will have opportunities to work on real-world projects, research initiatives and other projects at these centers and labs at the school, and across Rutgers University". This hints at projects but does not confirm if they are a *mandatory* graduation requirement.
#
# I will now proceed with the suggested search query to find more definitive information.
# ------------------------------------------------------------
#
# 项目 73: Tufts University - MS - Nutrition Epidemiology and Data Science
# ...
#
# I'm looking for "Capstone project", "Research thesis", "Comprehensive/qualifying exam", "Internship / practicum hours", "Mandatory fieldwork or research‐lab hours", "Professional portfolio", "Residency / clinical experience".
#
# The page states: "The requirements for the Master's degree in Statistics with specialization in Computational Finance are typically completed in two intensive years. The resulting MS Statistics degree includes additional courses in mathematical and investment finance, and computational science."
#
# It then details "Course Requirements" which are all credit-based courses.
#
# I also see "Internship, career fairs, and recruiting programs at Purdue provide students with great opportunities before and upon graduation." This mentions internships as opportunities but not as a mandatory graduation requirement.
#
# I've reviewed both provided URLs. Neither mentions any non-coursework graduation requirements like a thesis, capstone, or comprehensive exam for the MS in Statistics with Specialization in Computational Finance (MS CF). The second URL details course requirements but does not mention any additional requirements beyond coursework.
#
# Since I am asked to look for "MS Data Science in Finance", and the program URL is for "M.S. Statistics Degree with Specialization in Computational Finance", I will perform a search for "Purdue University, West Lafayette College of Science MS MS Data Science in Finance graduation requirement capstone thesis practicum exam site:.edu" to confirm.
#   response 3: An oral final exam is required.
# ------------------------------------------------------------
#
# 项目 80: University of Maryland, College Park - MS - M.S. in Applied Political Analytics
#   response 1: A major project is required.
#   response 2: A major project is required.
#   response 3: A major project is required.
# ------------------------------------------------------------
#
# 项目 81: University of Maryland, College Park - MS - Survey and Data Science
#   response 1: Not found
#   response 2: A research experience yielding a scholarly paper and a summer internship are required.
#   response 3: Not found
# ------------------------------------------------------------
#
# 项目 82: University of Maryland, College Park - PhD - Survey and Data Science
#   response 1: The PhD in Survey and Data Science requires a qualifying examination, a comprehensive examination, a residency requirement, and a dissertation.
#   response 2: Qualifying and comprehensive examinations, a dissertation, a four-semester doctoral seminar, and a three-semester residency are required.
#   response 3: Qualifying examination, comprehensive examination, residency, and a dissertation are required.
# ------------------------------------------------------------
#
# 项目 83: Northeastern University（Boston） - MS - Data and Systems
#   response 1: No additional graduation requirement.
#   response 2: Industry-based challenge project required.
#   response 3: Project or thesis option available.
# ------------------------------------------------------------
#
# 项目 84: Northeastern University（Boston） - MS - Data and Systems
#   response 1: Not found
#   response 2: Not found
#   response 3: Master's thesis or report option available.
# ------------------------------------------------------------
#
# 项目 85: Northeastern University（Boston） - MS - Applied Quantitative Methods and Social Analysis
#   response 1: No additional graduation requirement.
#   response 2: No additional graduation requirement.
#   response 3: The
# ------------------------------------------------------------
#
# 项目 86: Northeastern University（Boston） - MS - Applied Quantitative Methods and Social Analysis
#   response 1: No additional graduation requirement.
#   response 2: No additional graduation requirement.
#   response 3: No additional graduation requirement.
# ------------------------------------------------------------
#
# 项目 87: Northeastern University  - MS - Applied Quantitative Methods and Social Analysis
#   response 1: No additional graduation requirement.
#   response 2: No additional graduation requirement.
#   response 3: No additional graduation requirement.
# ------------------------------------------------------------
#
# 项目 88: Northeastern University  - MS - Applied Quantitative Methods and Social Analysis
#   response 1: No additional graduation requirement.
#   response 2: No additional graduation requirement.
#   response 3: No additional graduation requirement
# ------------------------------------------------------------
#
# 项目 89: University of Minnesota, Twin Cities - MS - M.S. in Data Science for Chemical Engineering and Materials Science
#   response 1: Capstone project option available.
#   response 2: Capstone project option available.
#   response 3: Capstone project option available.
# ------------------------------------------------------------
#
# 项目 90: University of Minnesota, Twin Cities - PHD - health informatics：Data Science & Informatics Track
#   response 1: Doctoral thesis required.
#   response 2: Capstone project and doctoral thesis research required.
#   response 3: Research thesis and internship are required.
# ------------------------------------------------------------
#
# 项目 91: Pennsylvania State University, University Park - PHD - Social Data Analytics
#   response 1: Comprehensive exam and dissertation research are required.
#   response 2: The
#   response 3: Comprehensive exam and dissertation required.
# ------------------------------------------------------------
#
# 项目 92: Rensselaer Polytechnic Institute - MENG - Biomedical Data Science
#   response 1: No additional graduation requirement.
#   response 2: No additional graduation requirement
#   response 3: No additional graduation requirement
# ------------------------------------------------------------
#
# 项目 93: Rensselaer Polytechnic Institute - MENG - Biomedical Data Science
#   response 1: No additional graduation requirement
#   response 2: No additional graduation requirement.
#   response 3: No additional graduation requirement.
# ------------------------------------------------------------
#
# 项目 94: University of Massachusetts, Amherst - MS - Economics
#   response 1: Research thesis or practicum option available.
#   response 2: Not found
#   response 3: Research thesis or field experience/practicum required.
# ------------------------------------------------------------
#
# 项目 95: University of Massachusetts, Amherst - MS - Economics
#   response 1: Not found
#   response 2: The
#   response 3: No additional graduation requirement.
# ------------------------------------------------------------
#
# 项目 96: University of Miami - MS -  Master of Science in Data Science：Smart Cities (School of Architecture)
#   response 1: Internship, project, or capstone required.
#   response 2: Internship, project, or capstone required.
#   response 3: Internship, project, or capstone required.
# ------------------------------------------------------------
#
# 项目 97: University of Miami - MS -  Master of Science in Data Science：Data Visualization (School of Communication)
#   response 1: Internship, project, or capstone option available.
#   response 2: Internship, project, or capstone required.
#   response 3: Internship, project, or capstone required.
# ------------------------------------------------------------
#
# 项目 98: University of Miami - MS -  Master of Science in Data Science：Marine & Atmospheric Science (Rosenstiel School of Marine & Atmospheric Sciences)
#   response 1: Internship, project, or capstone required.
#   response 2: Internship, project, or capstone required.
#   response 3: Internship, project, or capstone required.
# ------------------------------------------------------------
#
# 项目 99: University of Miami - MS -  Master of Science in Data Science：Educational Measurement & Statistics (School of Education & Human Development)
#   response 1: Internship, project, or capstone required.
#   response 2: Internship, project, or capstone required.
#   response 3: Internship, project, or capstone required.
# ------------------------------------------------------------
#
# 项目 100: University of Miami - MS -  Master of Science in Data Science：Marketing (Miami Herbert Business School)
#   response 1: Internship, project, or capstone required.
#   response 2: No response text
#   response 3: Internship, project, or capstone required.
# ------------------------------------------------------------
#
# 项目 101: Villanova University - MACDA - Master of Accounting with Data Analytics
#   response 1: A capstone program is required.
#   response 2: Capstone program required.
#   response 3: The
# ------------------------------------------------------------
#
# 项目 102: Villanova University - MACDA - Master of Accounting with Data Analytics
#   response 1: A capstone project is required.
#   response 2: A capstone program is required.
#   response 3: Capstone program required.
# ------------------------------------------------------------
#
# 项目 103: Villanova University - MBT - MASTER OF BUSINESS TAXATION WITH DATA ANALYTICS
#   response 1: No additional graduation requirement.
#   response 2: The
#   response 3: No additional graduation requirement.
# ------------------------------------------------------------
#
# 项目 104: Villanova University - MBT - MASTER OF BUSINESS TAXATION WITH DATA ANALYTICS
#   response 1: No additional graduation requirement.
#   response 2: No additional graduation requirement.
#   response 3: No additional graduation requirement.
# ------------------------------------------------------------
#
# 项目 105: Tulane University - MA - Political Economy with Data Analytics
#   response 1: Not found
#   response 2: No additional graduation requirement
#   response 3: No additional graduation requirement.
# ------------------------------------------------------------
#
# 项目 106: University at Buffalo, SUNY - MS - Data Analysis in the Social Sciences MS
#   response 1: Research project or thesis required.
#   response 2: A research project or thesis is required.
#   response 3: Research project or thesis required.
# ------------------------------------------------------------
#
# 项目 107: University at Buffalo, SUNY - MS - Data Analysis in the Social Sciences MS
#   response 1: Research project or thesis required.
#   response 2: Research project or thesis required.
#   response 3: A research project or thesis is required.
# ------------------------------------------------------------
#
# 项目 108: University at Buffalo, SUNY - MS - Materials Design and Innovation MS
#   response 1: Semester Master's Project required.
#   response 2: Semester Master's project required.
#   response 3: A semester master's project is required.
# ------------------------------------------------------------
#
# 项目 109: University at Buffalo, SUNY - PhD - Materials Design and Innovation PhD
#   response 1: Comprehensive exam and research thesis required.
#   response 2: Comprehensive exam and PhD thesis are required.
#   response 3: Comprehensive exam and PhD thesis required.
# ------------------------------------------------------------
#
# 项目 110: University of Delaware - MS  - Master of Science in Bioinformatics Data Science
#   response 1: A research thesis with an oral defense or a special problems project is required.
#   response 2: The Master of Science in Bioinformatics Data Science program requires either a research thesis with a final oral examination or special problems credits.
#   response 3: Research thesis or special problems project required.
# ------------------------------------------------------------
#
# 项目 111: University of Delaware - MS  - Master of Science in Bioinformatics Data Science
#   response 1: The
#   response 2: The
#   response 3: The Master of Science in Bioinformatics Data Science program requires either a research thesis with a final oral examination or a special problems project.
# ------------------------------------------------------------
#
# 项目 112: University of Delaware - PhD - Bioinformatics Data Science
#   response 1: Research thesis and comprehensive examinations are required.
#   response 2: The "PhD in Bioinformatics Data Science" page lists "Other Requirements" beyond coursework. These include:
#
# *   Formation of Graduate Dissertation Committee
# *   Successful completion of Graduate Preliminary Exam
# *   Research on a significant scientific problem
# *   Successful completion of Ph.D. Candidacy Exam
# *   Successful completion of Dissertation Defense
#
# The key non-coursework requirements are the preliminary exam, candidacy exam, significant research, and the dissertation defense. The formation of the committee supports these.
# Based on the instructions, I need to summarize these in one concise sentence.
#
# Research thesis, preliminary exam, candidacy exam, and dissertation defense are required.
#   response 3: Research thesis, preliminary exam, and candidacy exam are required.
# ------------------------------------------------------------
#
# 项目 113: University of Delaware - PhD - Bioinformatics Data Science
#   response 1: Preliminary exam, candidacy exam with research proposal defense, and a doctoral dissertation with an oral defense are required.
#   response 2: A research thesis, a preliminary examination, a candidacy examination, and a dissertation defense are required.
#   response 3: Research thesis and comprehensive/qualifying exams required.
# ------------------------------------------------------------
#
# 项目 114: Clemson University - PhD - Biomedical Data Science and Informatics
#   response 1: Qualifying exam, comprehensive examination, dissertation proposal, dissertation defense, and a dissertation are required.
#   response 2: Comprehensive examination and a research dissertation with a proposal and defense are required.
#   response 3: Comprehensive exam, dissertation proposal, and dissertation defense are required, along with a dissertation.
# ------------------------------------------------------------
#
# 项目 115: Clemson University - MS - Biomedical Data Science and Informatics
#   response 1: No additional graduation requirement.
#   response 2: No additional graduation requirement.
#   response 3: No additional graduation requirement.
# ------------------------------------------------------------
#
# 项目 116: Marquette University - MS - Criminal Justice Data Analytics
#   response 1: Practicum required
#   response 2: Practicum required.
#   response 3: Practicum required
# ------------------------------------------------------------
#
# 项目 117: Marquette University - MS - Criminal Justice Data Analytics
#   response 1: Practicum required
#   response 2: Practicum required
#   response 3: Practicum required.
# ------------------------------------------------------------
#
# 项目 118: Temple University - PSM - Bioinformatics and Biological Data Science PSM
#   response 1: Internship or research as part of a final capstone project is required.
#   response 2: An internship or research is required as part of the final capstone project.
#   response 3: Internship and capstone project required.
# ------------------------------------------------------------
#
# 项目 119: University of Oregon - MS - Education Policy and Leadership
#   response 1: An applied research project is required.
#   response 2: Applied research project required.
#   response 3: Applied research project/Master's project as a capstone required.
# ------------------------------------------------------------
#
# 项目 120: Illinois Institute of Technology - M.S. - Master of Science in Biomedical Modeling and Data Science
#   response 1: Not found
#   response 2: No additional graduation requirement.
#   response 3: The
# ------------------------------------------------------------
#
# 项目 121: University of Arizona - MS - Agricultural & Resource Econ (MS) - Applied Econometrics and Data Analytics
#   response 1: No additional graduation requirement.
#   response 2: No additional graduation requirement.
#   response 3: No additional graduation requirement.
# ------------------------------------------------------------
#
# 统计信息:
# 总项目数: 121
# 总回答数: 363
# 平均每项目回答数: 3.00
#
# 所有回答已保存到: /Users/yijingyang/Library/CloudStorage/OneDrive-个人/GradPilot/ProgramDB/AppliedDataScience/fields_records/Capstone或Thesis/Capstone或Thesis_gemini-2.5-flash_0_121_responses.txt

# %%
import json
import pandas as pd
import asyncio
from tqdm.asyncio import tqdm_asyncio
import sys
sys.path.append('/Users/yijingyang/Library/CloudStorage/OneDrive-个人/GradPilot/ProgramDB/AppliedDataScience')
json_file_path = "/Users/yijingyang/Library/CloudStorage/OneDrive-个人/GradPilot/ProgramDB/AppliedDataScience/fields_records/Capstone或Thesis/Capstone或Thesis_gemini-2.5-flash_0_121.json"
output_csv_path = "/Users/yijingyang/Library/CloudStorage/OneDrive-个人/GradPilot/ProgramDB/AppliedDataScience/fields_records/Capstone或Thesis/Capstone或Thesis.csv"

# %%
from call_api import async_call_gemini

async def extract_final_graduation_requirement_with_gemini(json_file_path, output_csv_path, 
                                                         model_name="gemini-2.5-flash", 
                                                         semaphore_limit=2):
    """
    使用Gemini API从三个回答中提取最终的毕业要求
    
    Args:
        json_file_path (str): JSON文件路径
        output_csv_path (str): 输出CSV文件路径
        model_name (str): Gemini模型名称
        semaphore_limit (int): 并发限制
    
    Returns:
        pd.DataFrame: 包含提取结果的DataFrame
    """
    
    # 限制并发数
    semaphore = asyncio.Semaphore(semaphore_limit)
    
    # 构建prompt模板
    prompt_template = """
You are analyzing graduation requirements for a graduate program. You have been given 3 different responses about what graduation requirements exist beyond regular coursework for this program.

Here are the 3 responses:

Response 1: "{response1}"
Response 2: "{response2}"  
Response 3: "{response3}"

TASK:
Based on these 3 responses, determine what the actual graduation requirement is using majority voting principles. If 2 or more responses say the same thing, that should be your answer. If all responses are different, choose the most specific and detailed one.

INSTRUCTIONS:
1. Read all 3 responses carefully
2. Identify what graduation requirement (beyond coursework) each response mentions
3. Apply majority voting - if 2+ responses agree, use that answer
4. If responses conflict, choose the most detailed/specific one
5. Give your final answer as a clear, concise statement
6. If the resposnes are Not found, that means there is no additional graduation requirement.

OUTPUT FORMAT:
Provide your answer as a single clear sentence describing the graduation requirement. Examples:
- "Capstone project required"
- "Research thesis required" 
- "Comprehensive exam required"
- "No additional graduation requirement"
- "Internship required"
- "Thesis or capstone project option available"

Do not explain your reasoning or provide multiple sentences. Just give the final requirement in one clear sentence.

FINAL ANSWER:
"""

    async def process_single_project(project):
        """处理单个项目"""
        async with semaphore:
            # 提取回答
            llm_responses = project.get('llm_reponses', {})
            
            response1 = ""
            response2 = ""
            response3 = ""
            
            for i in range(1, 4):
                response_key = f"response {i}"
                if response_key in llm_responses:
                    response_text = llm_responses[response_key].get('response_text', '')
                    if i == 1:
                        response1 = response_text
                    elif i == 2:
                        response2 = response_text
                    elif i == 3:
                        response3 = response_text
            
            # 构建prompt
            prompt = prompt_template.format(
                response1=response1 or "No response provided",
                response2=response2 or "No response provided", 
                response3=response3 or "No response provided"
            )
            
            # 调用Gemini API
            try:
                response = await async_call_gemini(
                    prompt,
                    model_name=model_name,
                    use_search=False,
                    url_context=False
                )
                
                # 处理API响应
                if isinstance(response, str) and response.startswith("Error:"):
                    return {
                        'final_requirement': f'API_ERROR: {response}',
                        'raw_api_response': response,
                        'status': 'API_ERROR'
                    }
                
                if not hasattr(response, "candidates") or not response.candidates:
                    return {
                        'final_requirement': 'API_ERROR: No candidates returned',
                        'raw_api_response': 'No candidates returned',
                        'status': 'API_ERROR'
                    }
                
                # 提取回答文本
                try:
                    api_response_text = response.candidates[0].content.parts[0].text.strip()
                except Exception as e:
                    return {
                        'final_requirement': f'PARSE_ERROR: {e}',
                        'raw_api_response': str(response),
                        'status': 'PARSE_ERROR'
                    }
                
                # 提取最终答案（寻找"FINAL ANSWER:"后的内容）
                final_answer = api_response_text
                if "FINAL ANSWER:" in api_response_text:
                    final_answer = api_response_text.split("FINAL ANSWER:")[-1].strip()
                
                # 清理答案（移除多余的格式）
                final_answer = final_answer.replace('\n', ' ').strip()
                if final_answer.startswith('-'):
                    final_answer = final_answer[1:].strip()
                if final_answer.startswith('"') and final_answer.endswith('"'):
                    final_answer = final_answer[1:-1].strip()
                
                return {
                    'final_requirement': final_answer,
                    'raw_api_response': api_response_text,
                    'status': 'SUCCESS'
                }
                
            except Exception as e:
                return {
                    'final_requirement': f'EXCEPTION_ERROR: {e}',
                    'raw_api_response': '',
                    'status': 'EXCEPTION_ERROR'
                }
    
    # 读取JSON文件
    print(f"读取文件: {json_file_path}")
    with open(json_file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    print(f"总项目数: {len(data)}")
    
    # 并行处理所有项目
    print("开始调用Gemini API提取最终毕业要求...")
    
    tasks = [process_single_project(project) for project in data]
    api_results = await tqdm_asyncio.gather(*tasks)
    
    # 整理结果
    results = []
    status_stats = {}
    
    for i, (project, api_result) in enumerate(zip(data, api_results)):
        # 提取基本信息
        university = project.get('大学英文名称', '')
        degree = project.get('学位', '')
        major = project.get('专业英文名称', '')
        school = project.get('所属院系', '')
        
        # 提取原始回答
        llm_responses = project.get('llm_reponses', {})
        original_responses = {}
        for j in range(1, 4):
            response_key = f"response {j}"
            if response_key in llm_responses:
                original_responses[f'原始回答{j}'] = llm_responses[response_key].get('response_text', '')
            else:
                original_responses[f'原始回答{j}'] = 'No response provided'
        
        # 统计状态
        status = api_result['status']
        if status not in status_stats:
            status_stats[status] = 0
        status_stats[status] += 1
        
        # 创建结果记录
        result_record = {
            '序号': i + 1,
            '大学英文名称': university,
            '学位': degree,
            '专业英文名称': major,
            '所属院系': school,
            '毕业要求': api_result['final_requirement'],
            '处理状态': status,
            'Gemini完整回答': api_result['raw_api_response']
        }
        
        # 添加原始回答
        result_record.update(original_responses)
        
        results.append(result_record)
    
    # 创建DataFrame并保存
    df = pd.DataFrame(results)
    df.to_csv(output_csv_path, index=False, encoding='utf-8-sig')
    
    # 打印统计信息
    print(f"\nGemini处理结果统计:")
    print(f"总项目数: {len(data)}")
    
    for status, count in status_stats.items():
        percentage = count / len(data) * 100
        print(f"{status}: {count} 个项目 ({percentage:.1f}%)")
    
    # 分析成功提取的要求类型
    successful_results = df[df['处理状态'] == 'SUCCESS']
    if len(successful_results) > 0:
        print(f"\n成功提取的毕业要求示例 (前10个):")
        for i, req in enumerate(successful_results['Gemini最终毕业要求'].head(10)):
            print(f"{i+1}. {req}")
    
    print(f"\n结果已保存到: {output_csv_path}")
    
    return df, status_stats

# 使用示例
async def main():
    """主函数"""
    df, stats = await extract_final_graduation_requirement_with_gemini(
        json_file_path=json_file_path,
        output_csv_path=output_csv_path,
        model_name="gemini-2.5-flash",
        semaphore_limit=2
    )
    
    return df, stats

# 在Jupyter中运行
if __name__ == "__main__":
    import nest_asyncio
    nest_asyncio.apply()
    
    # 运行函数
    df, stats = asyncio.run(main())
# Out:
# 读取文件: /Users/yijingyang/Library/CloudStorage/OneDrive-个人/GradPilot/ProgramDB/AppliedDataScience/fields_records/Capstone或Thesis/Capstone或Thesis_gemini-2.5-flash_0_121.json
# 总项目数: 121
# 开始调用Gemini API提取最终毕业要求...
# 100%|██████████| 121/121 [03:33<00:00,  1.77s/it]
# Gemini处理结果统计:
# 总项目数: 121
# SUCCESS: 118 个项目 (97.5%)
# PARSE_ERROR: 3 个项目 (2.5%)
#
# 成功提取的毕业要求示例 (前10个):
# 1. Research thesis required.
# 2. Written and oral qualifying exams, teaching trainee service, and research thesis are required.
# 3. Capstone project required.
# 4. No additional graduation requirement.
# 5. A development-related internship and a Second-Year Policy Analysis are required.
# 6. Capstone experiences, including a Spring Exercise and a Policy Analysis Exercise (PAE), are required.
# 7. No additional graduation requirement.
# 8. No additional graduation requirement
# 9. Capstone project required.
# 10. A qualifying exam, a thesis pre-proposal seminar, and a dissertation are required.
#
# 结果已保存到: /Users/yijingyang/Library/CloudStorage/OneDrive-个人/GradPilot/ProgramDB/AppliedDataScience/fields_records/Capstone或Thesis/Capstone或Thesis.csv

# %%
csv_file_path = "/Users/yijingyang/Library/CloudStorage/OneDrive-个人/GradPilot/ProgramDB/AppliedDataScience/fields_records/Capstone或Thesis/Capstone或Thesis.csv"
output_csv_path = "/Users/yijingyang/Library/CloudStorage/OneDrive-个人/GradPilot/ProgramDB/AppliedDataScience/fields_records/Capstone或Thesis/Capstone或Thesis_修复版.csv"

# %%
import pandas as pd
import asyncio
from tqdm.asyncio import tqdm_asyncio
from call_api import async_call_gemini

async def fix_gemini_errors(csv_file_path, output_csv_path, 
                           model_name="gemini-2.5-flash", 
                           max_retries=2,
                           semaphore_limit=2):
    """
    修复Gemini API调用中的错误回答
    
    Args:
        csv_file_path (str): 上一步生成的CSV文件路径
        output_csv_path (str): 修复后的输出CSV文件路径
        model_name (str): Gemini模型名称
        max_retries (int): 最大重试次数
        semaphore_limit (int): 并发限制
    
    Returns:
        pd.DataFrame: 修复后的DataFrame
    """
    
    # 限制并发数
    semaphore = asyncio.Semaphore(semaphore_limit)
    
    # 使用相同的prompt模板
    prompt_template = """
You are analyzing graduation requirements for a graduate program. You have been given 3 different responses about what graduation requirements exist beyond regular coursework for this program.

Here are the 3 responses:

Response 1: "{response1}"
Response 2: "{response2}"  
Response 3: "{response3}"

TASK:
Based on these 3 responses, determine what the actual graduation requirement is using majority voting principles. If 2 or more responses say the same thing, that should be your answer. If all responses are different, choose the most specific and detailed one.

INSTRUCTIONS:
1. Read all 3 responses carefully
2. Identify what graduation requirement (beyond coursework) each response mentions
3. Apply majority voting - if 2+ responses agree, use that answer
4. If responses conflict, choose the most detailed/specific one
5. Give your final answer as a clear, concise statement

OUTPUT FORMAT:
Provide your answer as a single clear sentence describing the graduation requirement. Examples:
- "Capstone project required"
- "Research thesis required" 
- "Comprehensive exam required"
- "No additional graduation requirement"
- "Internship required"
- "Thesis or capstone project option available"

Do not explain your reasoning or provide multiple sentences. Just give the final requirement in one clear sentence.

FINAL ANSWER:
"""

    async def retry_single_project(row, attempt_num):
        """重试单个项目的API调用"""
        async with semaphore:
            # 构建prompt
            prompt = prompt_template.format(
                response1=row.get('原始回答1', 'No response provided'),
                response2=row.get('原始回答2', 'No response provided'),
                response3=row.get('原始回答3', 'No response provided')
            )
            
            # 调用Gemini API
            try:
                response = await async_call_gemini(
                    prompt,
                    model_name=model_name,
                    use_search=False,
                    url_context=False
                )
                
                # 处理API响应
                if isinstance(response, str) and response.startswith("Error:"):
                    return {
                        'final_requirement': f'API_ERROR_RETRY_{attempt_num}: {response}',
                        'raw_api_response': response,
                        'status': 'API_ERROR',
                        'retry_attempt': attempt_num
                    }
                
                if not hasattr(response, "candidates") or not response.candidates:
                    return {
                        'final_requirement': f'API_ERROR_RETRY_{attempt_num}: No candidates returned',
                        'raw_api_response': 'No candidates returned',
                        'status': 'API_ERROR',
                        'retry_attempt': attempt_num
                    }
                
                # 提取回答文本
                try:
                    api_response_text = response.candidates[0].content.parts[0].text.strip()
                except Exception as e:
                    return {
                        'final_requirement': f'PARSE_ERROR_RETRY_{attempt_num}: {e}',
                        'raw_api_response': str(response),
                        'status': 'PARSE_ERROR',
                        'retry_attempt': attempt_num
                    }
                
                # 提取最终答案
                final_answer = api_response_text
                if "FINAL ANSWER:" in api_response_text:
                    final_answer = api_response_text.split("FINAL ANSWER:")[-1].strip()
                
                # 清理答案
                final_answer = final_answer.replace('\n', ' ').strip()
                if final_answer.startswith('-'):
                    final_answer = final_answer[1:].strip()
                if final_answer.startswith('"') and final_answer.endswith('"'):
                    final_answer = final_answer[1:-1].strip()
                
                # 验证答案是否合法（不为空且不包含错误标识）
                if (final_answer and 
                    len(final_answer.strip()) > 0 and 
                    not final_answer.upper().startswith(('API_ERROR', 'PARSE_ERROR', 'EXCEPTION_ERROR'))):
                    return {
                        'final_requirement': final_answer,
                        'raw_api_response': api_response_text,
                        'status': 'SUCCESS',
                        'retry_attempt': attempt_num
                    }
                else:
                    return {
                        'final_requirement': f'INVALID_RESPONSE_RETRY_{attempt_num}: {final_answer}',
                        'raw_api_response': api_response_text,
                        'status': 'PARSE_ERROR',
                        'retry_attempt': attempt_num
                    }
                
            except Exception as e:
                return {
                    'final_requirement': f'EXCEPTION_ERROR_RETRY_{attempt_num}: {e}',
                    'raw_api_response': '',
                    'status': 'EXCEPTION_ERROR',
                    'retry_attempt': attempt_num
                }
    
    # 读取CSV文件
    print(f"读取CSV文件: {csv_file_path}")
    df = pd.read_csv(csv_file_path, encoding='utf-8-sig')
    
    print(f"总项目数: {len(df)}")
    
    # 找出需要修复的行
    error_conditions = (
        (df['处理状态'] == 'PARSE_ERROR') | 
        (df['处理状态'] == 'API_ERROR') |
        (df['处理状态'] == 'EXCEPTION_ERROR') |
        (df['Gemini最终毕业要求'].str.contains('ERROR', case=False, na=False))
    )
    
    error_rows = df[error_conditions].copy()
    success_rows = df[~error_conditions].copy()
    
    print(f"需要修复的项目数: {len(error_rows)}")
    print(f"已成功的项目数: {len(success_rows)}")
    
    if len(error_rows) == 0:
        print("没有需要修复的项目!")
        return df
    
    # 对错误行进行重试
    fixed_rows = []
    
    for retry_attempt in range(1, max_retries + 1):
        if len(error_rows) == 0:
            break
            
        print(f"\n开始第 {retry_attempt} 次重试，处理 {len(error_rows)} 个项目...")
        
        # 并行重试
        tasks = [retry_single_project(row, retry_attempt) for _, row in error_rows.iterrows()]
        retry_results = await tqdm_asyncio.gather(*tasks)
        
        # 处理重试结果
        new_fixed_rows = []
        remaining_error_rows = []
        
        for (idx, row), retry_result in zip(error_rows.iterrows(), retry_results):
            # 更新行数据
            updated_row = row.copy()
            updated_row['Gemini最终毕业要求'] = retry_result['final_requirement']
            updated_row['处理状态'] = retry_result['status']
            updated_row['Gemini完整回答'] = retry_result['raw_api_response']
            updated_row[f'重试第{retry_attempt}次'] = f"状态: {retry_result['status']}, 结果: {retry_result['final_requirement'][:50]}..."
            
            if retry_result['status'] == 'SUCCESS':
                new_fixed_rows.append(updated_row)
                print(f"✓ 项目 {updated_row['序号']} 修复成功: {retry_result['final_requirement'][:50]}...")
            else:
                remaining_error_rows.append(updated_row)
        
        # 更新列表
        fixed_rows.extend(new_fixed_rows)
        error_rows = pd.DataFrame(remaining_error_rows) if remaining_error_rows else pd.DataFrame()
        
        print(f"第 {retry_attempt} 次重试结果:")
        print(f"  成功修复: {len(new_fixed_rows)} 个项目")
        print(f"  仍有错误: {len(remaining_error_rows)} 个项目")
    
    # 合并所有结果
    all_results = []
    
    # 添加原本成功的行
    for _, row in success_rows.iterrows():
        all_results.append(row)
    
    # 添加修复成功的行
    for row in fixed_rows:
        all_results.append(row)
    
    # 添加最终仍失败的行
    if len(error_rows) > 0:
        for _, row in error_rows.iterrows():
            all_results.append(row)
    
    # 创建最终DataFrame
    final_df = pd.DataFrame(all_results)
    final_df = final_df.sort_values('序号').reset_index(drop=True)
    
    # 保存结果
    final_df.to_csv(output_csv_path, index=False, encoding='utf-8-sig')
    
    # 打印最终统计
    print(f"\n=== 最终修复结果统计 ===")
    print(f"总项目数: {len(final_df)}")
    
    final_status_counts = final_df['处理状态'].value_counts()
    for status, count in final_status_counts.items():
        percentage = count / len(final_df) * 100
        print(f"{status}: {count} 个项目 ({percentage:.1f}%)")
    
    success_count = final_status_counts.get('SUCCESS', 0)
    improvement = success_count - len(success_rows)
    print(f"\n修复效果:")
    print(f"修复前成功项目: {len(success_rows)}")
    print(f"修复后成功项目: {success_count}")
    print(f"新增成功项目: {improvement}")
    print(f"最终成功率: {success_count/len(final_df)*100:.1f}%")
    
    print(f"\n修复后的结果已保存到: {output_csv_path}")
    
    return final_df

# 使用示例
async def main():
    """主函数"""
    df = await fix_gemini_errors(
        csv_file_path=csv_file_path,
        output_csv_path=output_csv_path,
        model_name="gemini-2.5-flash",
        max_retries=2,
        semaphore_limit=2
    )
    
    return df

# 在Jupyter中运行
if __name__ == "__main__":
    import nest_asyncio
    nest_asyncio.apply()
    
    # 运行函数
    df = asyncio.run(main())
# Out:
# 读取CSV文件: /Users/yijingyang/Library/CloudStorage/OneDrive-个人/GradPilot/ProgramDB/AppliedDataScience/fields_records/Capstone或Thesis/Capstone或Thesis.csv
# 总项目数: 121
# 需要修复的项目数: 3
# 已成功的项目数: 118
#
# 开始第 1 次重试，处理 3 个项目...
# 100%|██████████| 3/3 [00:15<00:00,  5.04s/it]
# ✓ 项目 83 修复成功: Industry-based challenge project required....
# ✓ 项目 119 修复成功: Applied research project required....
# 第 1 次重试结果:
#   成功修复: 2 个项目
#   仍有错误: 1 个项目
#
# 开始第 2 次重试，处理 1 个项目...
# 100%|██████████| 1/1 [00:08<00:00,  8.92s/it]
# ✓ 项目 113 修复成功: Preliminary exam, candidacy exam, research thesis,...
# 第 2 次重试结果:
#   成功修复: 1 个项目
#   仍有错误: 0 个项目
#
# === 最终修复结果统计 ===
# 总项目数: 121
# SUCCESS: 121 个项目 (100.0%)
#
# 修复效果:
# 修复前成功项目: 118
# 修复后成功项目: 121
# 新增成功项目: 3
# 最终成功率: 100.0%
#
# 修复后的结果已保存到: /Users/yijingyang/Library/CloudStorage/OneDrive-个人/GradPilot/ProgramDB/AppliedDataScience/fields_records/Capstone或Thesis/Capstone或Thesis_修复版.csv
